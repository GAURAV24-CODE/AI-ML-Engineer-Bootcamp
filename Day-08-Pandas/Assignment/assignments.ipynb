# %%
import pandas as pd

# %%
# task 1 - Create a Pandas Series
# Create a Series containing 5 student marks

marks = pd.Series([85, 90, 78, 92, 88])

# Display the Series
print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# dtype: int64

# %%
# task 2 - Create a DataFrame
# Create a DataFrame containing student names, ages and marks

data = {
    "Name": ["Gaurav", "Rahul", "Amit", "Sneha", "Priya"],
    "Age": [22, 23, 21, 22, 24],
    "Marks": [85, 90, 78, 92, 88]
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#      Name  Age  Marks
# 0  Gaurav   22     85
# 1   Rahul   23     90
# 2    Amit   21     78
# 3   Sneha   22     92
# 4   Priya   24     88

# %%
# task 3 - Display DataFrame Information
# Display the shape, columns and data types

print("Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)
# Out:
# Shape: (5, 3)
#
# Columns:
# Index(['Name', 'Age', 'Marks'], dtype='str')
#
# Data Types:
# Name       str
# Age      int64
# Marks    int64
# dtype: object

# %%
# task 4 - Select Columns
# Select and display the Name and Marks columns

selected_columns = df[["Name", "Marks"]]

# Display selected columns
print(selected_columns)
# Out:
#      Name  Marks
# 0  Gaurav     85
# 1   Rahul     90
# 2    Amit     78
# 3   Sneha     92
# 4   Priya     88

# %%
# task 5 - Select Rows Using loc
# Display the first and third rows using loc

first_row = df.loc[0]
third_row = df.loc[2]

# Display the rows
print("First Row:")
print(first_row)

print("\nThird Row:")
print(third_row)
# Out:
# First Row:
# Name     Gaurav
# Age          22
# Marks        85
# Name: 0, dtype: object
#
# Third Row:
# Name     Amit
# Age        21
# Marks      78
# Name: 2, dtype: object

# %%
# task 6 - Select Rows Using iloc
# Display the first three rows using iloc

selected_rows = df.iloc[0:3]

# Display the selected rows
print(selected_rows)
# Out:
#      Name  Age  Marks
# 0  Gaurav   22     85
# 1   Rahul   23     90
# 2    Amit   21     78

# %%
# task 7 - Filter Data
# Display students who scored more than 85 marks

filtered_data = df[df["Marks"] > 85]

# Display filtered data
print(filtered_data)
# Out:
#     Name  Age  Marks
# 1  Rahul   23     90
# 3  Sneha   22     92
# 4  Priya   24     88

# %%
# task 8 - Sort DataFrame
# Sort students according to marks in descending order

sorted_df = df.sort_values("Marks", ascending=False)

# Display the sorted DataFrame
print(sorted_df)
# Out:
#      Name  Age  Marks
# 3   Sneha   22     92
# 1   Rahul   23     90
# 4   Priya   24     88
# 0  Gaurav   22     85
# 2    Amit   21     78

# %%
# task 9 - Add a New Column
# Create a Result column based on student marks

df["Result"] = df["Marks"] >= 40

# Display the updated DataFrame
print(df)
# Out:
#      Name  Age  Marks  Result
# 0  Gaurav   22     85    True
# 1   Rahul   23     90    True
# 2    Amit   21     78    True
# 3   Sneha   22     92    True
# 4   Priya   24     88    True

# %%
# task 10 - Calculate Basic Statistics
# Calculate the sum, average, maximum and minimum marks

print("Total Marks:", df["Marks"].sum())
print("Average Marks:", df["Marks"].mean())
print("Maximum Marks:", df["Marks"].max())
print("Minimum Marks:", df["Marks"].min())
# Out:
# Total Marks: 433
# Average Marks: 86.6
# Maximum Marks: 92
# Minimum Marks: 78
