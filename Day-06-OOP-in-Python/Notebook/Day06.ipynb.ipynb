# %% [markdown]
# # Day 6 - OOP
# AI/ML Engineer Bootcamp

# %% [markdown]
# ## Class & Object

# %%
class Student:
    pass
student1=Student()
print(student1)
# Out:
# <__main__.Student object at 0x000002159FAAE7B0>

# %% [markdown]
# ## Attributes

# %%
class Student:
    name='Gaurav'
    age=22
s=Student()
print(s.name,s.age)
# Out:
# Gaurav 22

# %% [markdown]
# ## Constructor

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
print(Student('Gaurav',22).name)
# Out:
# Gaurav

# %% [markdown]
# ## Class vs Instance

# %%
class Student:
    college='SSBT'
    def __init__(self,name):
        self.name=name
s=Student('Gaurav')
print(s.name,s.college)
# Out:
# Gaurav SSBT

# %% [markdown]
# ## Method

# %%
class Car:
    def __init__(self,b):
        self.brand=b
    def start(self):
        print(self.brand,'Car Started')
Car('BMW').start()
# Out:
# BMW Car Started

# %% [markdown]
# ## Inheritance

# %%
class Animal:
    def sound(self):
        print('Animal makes sound')
class Dog(Animal):
    def bark(self):
        print('Dog Barks')
d=Dog(); d.sound(); d.bark()
# Out:
# Animal makes sound
# Dog Barks

# %% [markdown]
# ## Polymorphism

# %%
class Dog:
    def sound(self):
        print('Dog Barks')
class Cat:
    def sound(self):
        print('Cat Meows')
for x in [Dog(),Cat()]:
    x.sound()
# Out:
# Dog Barks
# Cat Meows

# %% [markdown]
# ## Encapsulation

# %%
class BankAccount:
    def __init__(self,b):
        self.__balance=b
    def show_balance(self):
        print(self.__balance)
BankAccount(5000).show_balance()
# Out:
# 5000

# %% [markdown]
# ## Abstraction

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self,r):
        self.r=r
    def area(self):
        return 3.14*self.r*self.r
print(Circle(5).area())
# Out:
# 78.5
