# %%
# ============================================================
# Task 1
# Create a list of five fruits and print it.
# ============================================================

fruits = ["Apple", "Banana", "Mango", "Orange", "Grapes"]

print("Task 1")
print(fruits)
# Out:
# Task 1
# ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']

# %%
#✅ Task 2: Find First and Last Element

# %%
numbers = [10, 20, 30, 40, 50]

print("List =", numbers)
print("First Element =", numbers[0])
print("Last Element =", numbers[-1])
# Out:
# List = [10, 20, 30, 40, 50]
# First Element = 10
# Last Element = 50

# %%
# ✅ Task 3: Tuple
fruits = ("Apple", "Mango", "Banana")

print("Tuple =", fruits)

for fruit in fruits:
    print(fruit)
# Out:
# Tuple = ('Apple', 'Mango', 'Banana')
# Apple
# Mango
# Banana

# %%
# ✅ Task 4: Remove Duplicate Values
numbers = [10, 20, 20, 30, 40, 40]

unique = set(numbers)

print("Original List =", numbers)
print("Unique Values =", unique)
# Out:
# Original List = [10, 20, 20, 30, 40, 40]
# Unique Values = {40, 10, 20, 30}

# %%
# ✅ Task 5: Student Dictionary
student = {}

student["Name"] = input("Enter Name: ")
student["Age"] = input("Enter Age: ")
student["Course"] = input("Enter Course: ")

print("\nStudent Details")

for key, value in student.items():
    print(key, ":", value)
# Out:
# Student Details
# Name : python
# Age :
# Course : Escape
